# %%
# from __future__ import print_function, division

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 1

# %%
# TODO define gaussian function here
def gauss(x, mean, variance, height):
    return (height *(1/(np.sqrt(2 * np.pi * variance))) *np.exp(-(x-mean)**2)/(2*variance))

# %%
# TODO plot gaussians here
x = np.linspace(-5, 5, 100)
y = gauss(x, 0, 4, 7)
plt.plot(x, y)
plt.show()
plt.scatter(x, y)
plt.show()

# %%
# TODO fit gaussians, with known parameters, here
from scipy.optimize import curve_fit
params, cov = curve_fit(gauss, x, y)
print (params)

# TODO plot result
plt.plot(x, gauss(x, *params))
plt.plot(x, y)
# Out:
# [-1.71892836e-09  6.67657965e-01  4.77352394e-01]
# C:\Users\theol\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# TODO: load data here
data = np.loadtxt('HDalpha_data')
array = np.array(data)
xdata = array[:,0]
ydata = array[:,1]

# %%
# TODO: plot it
plt.plot(xdata, ydata)

# %%
# TODO: plot data as emission signal
ydata = -ydata
plt.plot(xdata, ydata)

# %%
# TODO: fit a function to this bad boy
def gauss1(x, mean, variance):
           return (1/(np.sqrt(2 * np.pi * variance))) *np.exp(-(x-mean)**2)/(2*variance)  

def doubleGauss(x, mean, variance, mean2, variance2, height, height2):
    return (height*(gauss1(x, mean, variance)) + height2*(gauss1(x, mean2, variance2)))

params, cov = curve_fit(doubleGauss, xdata, ydata,p0=(13127.8, 1.2, 13132, 1.5, .00000009, .000000002))
#print (params)
plt.plot(xdata, doubleGauss(xdata, *params))
plt.plot(xdata, ydata)
plt.title('Swank-ass Double Gaussian Curves')
# Out:
# C:\Users\theol\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0.5,1,u'Swank-ass Double Gaussian Curves')

# %% [markdown]
# # Part 2

# %%
# TODO: part 2
import random

x = np.random.random(100)
y = np.random.random(100)
f, ((ax0, ax1),(ax2, ax3)) = plt.subplots(2,2)
ax0.scatter(x[1:25],y[1:25], color = 'r', alpha = 1, s = y[1:25]*30)
ax1.scatter(x[25:50],y[25:50], color = 'g', alpha = .5, s = x[25:50]*30)
ax2.scatter(x[50:75],y[50:75], color = 'm', alpha = .25, s = y[50:75]*30)
ax3.scatter(x[75:100],y[75:100], color = 'b', alpha = .25849, s = x[75:100]*30)

ax0.set_xticks([])
ax0.set_yticks([])
ax1.set_xticks([])
ax1.set_yticks([])
ax2.set_xticks([])
ax2.set_yticks([])
ax3.set_xticks([])
ax3.set_yticks([])
ax0.set_title('Plot 1')
ax1.set_title('Plot 2')
ax2.set_title('Plot 3')
ax3.set_title('Plot 4')
plt.suptitle('The Four Horsemen of the Apocalypse', fontsize =20)
plt.subplots_adjust(top=.85)
plt.show()

# %% [markdown]
# # Part 3

# %%
def flux_for_dipole(x_pos, y_pos, Q_vals, X, Y):
    """
    Returns the flux based on the information of the charges
    and the grid of the plot.
    Code modified from Physics 113, written by Blas Cabrera
    """
    flux = np.zeros((len(X), len(Y)))
    x_m = np.outer(np.ones((X.size)), X); 
    y_m = np.outer(Y, np.ones((Y.size))); 
    for n in range(len(Q_vals)):
        flux += 2*np.pi*Q_vals[n]*(1 - (x_pos[n]-x_m)/np.sqrt((y_pos[n]-y_m)**2+(x_pos[n]-x_m)**2))
    return flux

# %%
# TODO create arrays of information
N = 100
xposition = [3, 6]
yposition = [4, 6]
charges = [-5, 8]
X = np.linspace(-31.5, 31.5, 64)
Y = np.linspace(-31.5, 31.5, 64)
# TODO get flux
Z = flux_for_dipole(xposition, yposition, charges, X, Y)
# TODO plot contours of the flux
plt.contour(X, Y, Z, N)
plt.show()
